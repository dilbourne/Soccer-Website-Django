# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = "http://premierleague.com/tables"

# %%
content_ = requests.get(url).content
soup = BeautifulSoup(content_,'html.parser')

# %% [markdown]
# # Scraping premier league table data  (comp-season=274)

# %%
tables = soup.find_all("tr",{"data-compseason":"274"})
tbody_data = []
thead_data = getHeadingsAndAbbreviations()
for index, row in enumerate(tables):
    a = str([tr for tr in row])
    s = BeautifulSoup(a,'html.parser')
    tds = s.find_all("td")
    almost = [t.text.replace('\n',"").strip() for t in tds][2:-2]
    pattern = '([a-z]|[0-9])[A-Z]'
    if re.search(pattern,almost[0]):
        span = re.search(pattern,almost[0]).span()
        after = [almost[0][:(span[1]-1)],almost[0][(span[1]-1):].strip()]
        final = [str(index+1),*[after],*almost[1:]]
        tbody_data.append({ key: value for (key,value) in zip(thead_data,final)})

# %%
tbody_data
# Out:
# [{'Position': '1',
#   'Club': ['Liverpool', 'LIV'],
#   'Played': '29',
#   'Won': '27',
#   'Drawn': '1',
#   'Lost': '1',
#   'GF': '66',
#   'GA': '21',
#   'GD': '+45',
#   'Points': '82'},
#  {'Position': '2',
#   'Club': ['Manchester City', 'MCI'],
#   'Played': '28',
#   'Won': '18',
#   'Drawn': '3',
#   'Lost': '7',
#   'GF': '68',
#   'GA': '31',
#   'GD': '+37',
#   'Points': '57'},
#  {'Position': '3',
#   'Club': ['Leicester City', 'LEI'],
#   'Played': '29',
#   'Won': '16',
#   'Drawn': '5',
#   'Lost': '8',
#   'GF': '58',
#   'GA': '28',
#   'GD': '+30',
#   'Points': '53'},
#  {'Position': '4',
#   'Club': ['Chelsea', 'CHE'],
#   'Played': '29',
#   'Won': '14',
#   'Drawn': '6',
#   'Lost': '9',
#   'GF': '51',
#   'GA': '39',
#   'GD': '+12',
#   'Points': '48'},
#  {'Position': '5',
#   'Club': ['Manchester United', 'MUN'],
#   'Played': '29',
#   'Won': '12',
#   'Drawn': '9',
#   'Lost': '8',
#   'GF': '44',
#   'GA': '30',
#   'GD': '+14',
#   'Points': '45'},
#  {'Position': '6',
#   'Club': ['Wolverhampton Wanderers', 'WOL'],
#   'Played': '29',
#   'Won': '10',
#   'Drawn': '13',
#   'Lost': '6',
#   'GF': '41',
#   'GA': '34',
#   'GD': '+7',
#   'Points': '43'},
#  {'Position': '7',
#   'Club': ['Sheffield United', 'SHU'],
#   'Played': '28',
#   'Won': '11',
#   'Drawn': '10',
#   'Lost': '7',
#   'GF': '30',
#   'GA': '25',
#   'GD': '+5',
#   'Points': '43'},
#  {'Position': '8',
#   'Club': ['Tottenham Hotspur', 'TOT'],
#   'Played': '29',
#   'Won': '11',
#   'Drawn': '8',
#   'Lost': '10',
#   'GF': '47',
#   'GA': '40',
#   'GD': '+7',
#   'Points': '41'},
#  {'Position': '9',
#   'Club': ['Arsenal', 'ARS'],
#   'Played': '28',
#   'Won': '9',
#   'Drawn': '13',
#   'Lost': '6',
#   'GF': '40',
#   'GA': '36',
#   'GD': '+4',
#   'Points': '40'},
#  {'Position': '10',
#   'Club': ['Burnley', 'BUR'],
#   'Played': '29',
#   'Won': '11',
#   'Drawn': '6',
#   'Lost': '12',
#   'GF': '34',
#   'GA': '40',
#   'GD': '-6',
#   'Points': '39'},
#  {'Position': '11',
#   'Club': ['Crystal Palace', 'CRY'],
#   'Played': '29',
#   'Won': '10',
#   'Drawn': '9',
#   'Lost': '10',
#   'GF': '26',
#   'GA': '32',
#   'GD': '-6',
#   'Points': '39'},
#  {'Position': '12',
#   'Club': ['Everton', 'EVE'],
#   'Played': '29',
#   'Won': '10',
#   'Drawn': '7',
#   'Lost': '12',
#   'GF': '37',
#   'GA': '46',
#   'GD': '-9',
#   'Points': '37'},
#  {'Position': '13',
#   'Club': ['Newcastle United', 'NEW'],
#   'Played': '29',
#   'Won': '9',
#   'Drawn': '8',
#   'Lost': '12',
#   'GF': '25',
#   'GA': '41',
#   'GD': '-16',
#   'Points': '35'},
#  {'Position': '14',
#   'Club': ['Southampton', 'SOU'],
#   'Played': '29',
#   'Won': '10',
#   'Drawn': '4',
#   'Lost': '15',
#   'GF': '35',
#   'GA': '52',
#   'GD': '-17',
#   'Points': '34'},
#  {'Position': '15',
#   'Club': ['Brighton and Hove Albion', 'BHA'],
#   'Played': '29',
#   'Won': '6',
#   'Drawn': '11',
#   'Lost': '12',
#   'GF': '32',
#   'GA': '40',
#   'GD': '-8',
#   'Points': '29'},
#  {'Position': '16',
#   'Club': ['West Ham United', 'WHU'],
#   'Played': '29',
#   'Won': '7',
#   'Drawn': '6',
#   'Lost': '16',
#   'GF': '35',
#   'GA': '50',
#   'GD': '-15',
#   'Points': '27'},
#  {'Position': '17',
#   'Club': ['Watford', 'WAT'],
#   'Played': '29',
#   'Won': '6',
#   'Drawn': '9',
#   'Lost': '14',
#   'GF': '27',
#   'GA': '44',
#   'GD': '-17',
#   'Points': '27'},
#  {'Position': '18',
#   'Club': ['Bournemouth', 'BOU'],
#   'Played': '29',
#   'Won': '7',
#   'Drawn': '6',
#   'Lost': '16',
#   'GF': '29',
#   'GA': '47',
#   'GD': '-18',
#   'Points': '27'},
#  {'Position': '19',
#   'Club': ['Aston Villa', 'AVL'],
#   'Played': '28',
#   'Won': '7',
#   'Drawn': '4',
#   'Lost': '17',
#   'GF': '34',
#   'GA': '56',
#   'GD': '-22',
#   'Points': '25'},
#  {'Position': '20',
#   'Club': ['Norwich City', 'NOR'],
#   'Played': '29',
#   'Won': '5',
#   'Drawn': '6',
#   'Lost': '18',
#   'GF': '25',
#   'GA': '52',
#   'GD': '-27',
#   'Points': '21'}]

# %% [markdown]
# # Scraping Column Headings and their shortened forms

# %%
def getHeadingsAndAbbreviations():
    thead = soup.find_all("thead")
    th_soup = BeautifulSoup(str(thead[0]),'html.parser')
    ths = th_soup.find_all("th",{"scope":"col"})
    almost_ = [th.text.replace('\n',"") for th in ths][2:-2]

    pattern = '([a-z]|[0-9])[A-Z]'
    final_ = ['Position']
    for i in almost_:
        # if i has a shorter version, ignore it / cut it out
        if re.search(pattern,i):
            # get start and end indices of where the pattern matches from span
            span = re.search(pattern,i).span()
            final_.append(i[:(span[1]-1)])
        # else just add it
        else:
            final_.append(i)
    return final_

# %%
getHeadingsAndAbbreviations()
# Out:
# ['Position',
#  'Club',
#  'Played',
#  'Won',
#  'Drawn',
#  'Lost',
#  'GF',
#  'GA',
#  'GD',
#  'Points']

# %%
def getTableBodyData(thead_data):
    import requests
    from bs4 import BeautifulSoup
    import re
    
    url = "http://premierleague.com/tables"
    content_ = requests.get(url).content
    soup = BeautifulSoup(content_,'html.parser')
    
    tables = soup.find_all("tr",{"data-compseason":"274"})
    tbody_data = []

    """for index, row in enumerate(tables):
        row_soup = BeautifulSoup(str(row),'html.parser')
        badge_src = row_soup.find("img",{"class":"badge-image"})['src']
        a = str([tr for tr in row])
        s = BeautifulSoup(a,'html.parser')
        tds = s.find_all("td")
        almost = [t.text.replace('\n',"").strip() for t in tds][2:-2]
        pattern = '([a-z]|[0-9])[A-Z]'
        if re.search(pattern,almost[0]):
            span = re.search(pattern,almost[0]).span()
            after = (almost[0][:(span[1]-1)],almost[0][(span[1]-1):].strip(),badge_src)
            final = [*str(index),*[after],*almost[1:]]
            tbody_data.append({ key: value for (key,value) in zip(thead_data,final)})

    return tbody_data"""
    for index, row in enumerate(tables):
        print(index,":",row)

# %%
getTableBodyData(getHeadingsAndAbbreviations())
# Out:
# 0 : <tr class="tableDark" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="10" data-filtered-table-row-abbr="10" data-filtered-table-row-name="Liverpool" data-filtered-table-row-opta="t14" data-position="1">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">1</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 1
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/10/Liverpool/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
# </img></span>
# <span class="long">Liverpool</span>
# <span class="short">LIV</span>
# </a>
# </td>
# <td>29</td>
# <td>27</td>
# <td>1</td>
# <td>1</td>
# <td class="hideSmall">66</td>
# <td class="hideSmall">21</td>
# <td>
#         +45
#
#  </td>
# <td class="points">82</td>
# <td class="form hideMed">
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46849" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
# </img></span>
# <span class="score">4 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t20@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Southampton">SOU</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46861" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 15 February 2020</span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46870" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Monday 24 February 2020</span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x"/>
# </span>
# <span class="score">3 <span>-</span>2</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t21@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="West Ham United">WHU</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46883" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 29 February 2020</span>
# <span class="teamName"><abbr title="Watford">WAT</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t57.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t57@x2.png 2x"/>
# </span>
# <span class="score">3 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46890" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 7 March 2020</span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t91@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Bournemouth">BOU</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t3.png, https://resources.premierleague.com/premierleague/badges/20/t3@x2.png 2x"/>
# <span class="visuallyHidden">Arsenal</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46955" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t3@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>
# 1 : <tr class="tableMid" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="11" data-filtered-table-row-abbr="11" data-filtered-table-row-name="Manchester City" data-filtered-table-row-opta="t43" data-position="2">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">2</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 2
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/11/Manchester-City/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t43@x2.png 2x"/>
# </span>
# <span class="long">Manchester City</span>
# <span class="short">MCI</span>
# </a>
# </td>
# <td>28</td>
# <td>18</td>
# <td>3</td>
# <td>7</td>
# <td class="hideSmall">68</td>
# <td class="hideSmall">31</td>
# <td>
#         +37
#
#  </td>
# <td class="points">57</td>
# <td class="form hideMed">
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46840" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Tuesday 21 January 2020</span>
# <span class="teamName"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t49@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46852" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 2 February 2020</span>
# <span class="teamName"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t6@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46860" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Wednesday 19 February 2020</span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t21@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="West Ham United">WHU</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46869" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 22 February 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46891" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 8 March 2020</span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t91.png, https://resources.premierleague.com/premierleague/badges/20/t91@x2.png 2x"/>
# <span class="visuallyHidden">AFC Bournemouth</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46961" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t91@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Bournemouth">BOU</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>
# 2 : <tr class="tableMid" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="26" data-filtered-table-row-abbr="26" data-filtered-table-row-name="Leicester City" data-filtered-table-row-opta="t13" data-position="3">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">3</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 3
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/26/Leicester-City/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t13@x2.png 2x"/>
# </span>
# <span class="long">Leicester City</span>
# <span class="short">LEI</span>
# </a>
# </td>
# <td>29</td>
# <td>16</td>
# <td>5</td>
# <td>8</td>
# <td class="hideSmall">58</td>
# <td class="hideSmall">28</td>
# <td>
#         +30
#
#  </td>
# <td class="points">53</td>
# <td class="form hideMed">
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46848" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>2</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46864" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Friday 14 February 2020</span>
# <span class="teamName"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t39@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46869" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 22 February 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46881" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Friday 28 February 2020</span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="score">1 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46889" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Monday 9 March 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="score">4 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t49.png, https://resources.premierleague.com/premierleague/badges/20/t49@x2.png 2x"/>
# <span class="visuallyHidden">Sheffield United</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46960" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t49@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>
# 3 : <tr class="tableMid" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="4" data-filtered-table-row-abbr="4" data-filtered-table-row-name="Chelsea" data-filtered-table-row-opta="t8" data-position="4">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">4</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 4
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/4/Chelsea/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t8@x2.png 2x"/>
# </span>
# <span class="long">Chelsea</span>
# <span class="short">CHE</span>
# </a>
# </td>
# <td>29</td>
# <td>14</td>
# <td>6</td>
# <td>9</td>
# <td class="hideSmall">51</td>
# <td class="hideSmall">39</td>
# <td>
#         +12
#
#  </td>
# <td class="points">48</td>
# <td class="form hideMed">
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46848" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>2</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46858" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Monday 17 February 2020</span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>2</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46867" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 22 February 2020</span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t6@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46876" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 29 February 2020</span>
# <span class="teamName"><abbr title="Bournemouth">BOU</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t91@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>2</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46887" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 8 March 2020</span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="score">4 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t11@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Everton">EVE</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# <span class="visuallyHidden">Norwich City</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46957" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>
# 4 : <tr class="tableLight" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="12" data-filtered-table-row-abbr="12" data-filtered-table-row-name="Manchester United" data-filtered-table-row-opta="t1" data-position="5">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">5</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 5
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/12/Manchester-United/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t1@x2.png 2x"/>
# </span>
# <span class="long">Manchester United</span>
# <span class="short">MUN</span>
# </a>
# </td>
# <td>29</td>
# <td>12</td>
# <td>9</td>
# <td>8</td>
# <td class="hideSmall">44</td>
# <td class="hideSmall">30</td>
# <td>
#         +14
#
#  </td>
# <td class="points">45</td>
# <td class="form hideMed">
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46850" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t39@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46858" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Monday 17 February 2020</span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>2</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46871" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 23 February 2020</span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="score">3 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t57.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t57@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Watford">WAT</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46878" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 1 March 2020</span>
# <span class="teamName"><abbr title="Everton">EVE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t11@x2.png 2x"/>
# </span>
# <span class="score">1 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46891" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 8 March 2020</span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t43@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t31.png, https://resources.premierleague.com/premierleague/badges/20/t31@x2.png 2x"/>
# <span class="visuallyHidden">Crystal Palace</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46958" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Crystal Palace">CRY</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t31@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>
# 5 : <tr class="" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="38" data-filtered-table-row-abbr="38" data-filtered-table-row-name="Wolverhampton Wanderers" data-filtered-table-row-opta="t39" data-position="6">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">6</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 6
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/38/Wolverhampton-Wanderers/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t39@x2.png 2x"/>
# </span>
# <span class="long">Wolverhampton Wanderers</span>
# <span class="short">WOL</span>
# </a>
# </td>
# <td>29</td>
# <td>10</td>
# <td>13</td>
# <td>6</td>
# <td class="hideSmall">41</td>
# <td class="hideSmall">34</td>
# <td>
#         +7
#
#  </td>
# <td class="points">43</td>
# <td class="form hideMed">
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46850" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Manchester United">MUN</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t1@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t39@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46864" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Friday 14 February 2020</span>
# <span class="teamName"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t39@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46874" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# ...
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Tuesday 21 January 2020</span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t57.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t57@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Watford">WAT</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46845" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Bournemouth">BOU</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t91@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46856" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 16 February 2020</span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>3</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t6@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46873" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 22 February 2020</span>
# <span class="teamName"><abbr title="Southampton">SOU</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t20@x2.png 2x"/>
# </span>
# <span class="score">2 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46889" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Monday 9 March 2020</span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="score">4 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t11.png, https://resources.premierleague.com/premierleague/badges/20/t11@x2.png 2x"/>
# <span class="visuallyHidden">Everton</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46959" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Everton">EVE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t11@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t7@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Aston Villa">AVL</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>
# 19 : <tr class="tableMid" data-compseason="274" data-filtered-entry-size="20" data-filtered-table-row="14" data-filtered-table-row-abbr="14" data-filtered-table-row-name="Norwich City" data-filtered-table-row-opta="t45" data-position="20">
# <td class="revealMore" role="button" style="display:none;" tabindex="0">
# <div class="icn chevron-downgrey-normal"></div>
# </td>
# <td class="pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="value">20</span>
# <span class="movement none">
# <span class="tooltipContainer tooltip-left" role="tooltip">
# <span class="tooltip-content">Previous Position
#                             <span class="resultHighlight">
#                                 20
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="team" scope="row">
# <a href="/clubs/14/Norwich-City/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x"/>
# </span>
# <span class="long">Norwich City</span>
# <span class="short">NOR</span>
# </a>
# </td>
# <td>29</td>
# <td>5</td>
# <td>6</td>
# <td>18</td>
# <td class="hideSmall">25</td>
# <td class="hideSmall">52</td>
# <td>
#         -27
#
#  </td>
# <td class="points">21</td>
# <td class="form hideMed">
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46851" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 1 February 2020</span>
# <span class="teamName"><abbr title="Newcastle United">NEW</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t4@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46861" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 15 February 2020</span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="score">0 <span>-</span>1</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46874" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Sunday 23 February 2020</span>
# <span class="teamName"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t39@x2.png 2x"/>
# </span>
# <span class="score">3 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46881" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Friday 28 February 2020</span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="score">1 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t13@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46892" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 7 March 2020</span>
# <span class="teamName"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t49@x2.png 2x"/>
# </span>
# <span class="score">1 <span>-</span>0</span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="icn arrow-right"></span>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8.png, https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# <span class="visuallyHidden">Chelsea</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/46957" role="tooltip">
# <span class="tooltip-content">
# <div class="matchAbridged">
# <span class="matchInfo">Saturday 02 May 2020</span>
# <span class="teamName"><abbr title="Chelsea">CHE</abbr></span>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t8@x2.png 2x"/>
# </span>
# <time>15:00</time>
# <span class="badge badge-image-container" data-size="20" data-widget="club-badge-image">
# <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x"/>
# </span>
# <span class="teamName"><abbr title="Norwich City">NOR</abbr></span>
# <span class="icn arrow-right"></span>
# </div></span>
# </a></span></td></tr>

# %%
[*str(10)]
# Out:
# ['1', '0']

# %%
[str(10),['Liverpool','LIV','https://dhffjghgsdf']]
# Out:
# ['10', ['Liverpool', 'LIV', 'https://dhffjghgsdf']]
